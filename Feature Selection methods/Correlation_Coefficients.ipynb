# %%
import pandas as pd
import numpy as np

data=pd.DataFrame({
    'size_sqft':[1000,1200, 2000, 2500, 3000],
    'tiles_count':[100,150,200,250,300],
    'price':[200000,300000,400000,500000,600000]
})
data
# Out:
#    size_sqft  tiles_count   price
# 0       1000          100  200000
# 1       1200          150  300000
# 2       2000          200  400000
# 3       2500          250  500000
# 4       3000          300  600000

# %%
correlation_matrix=data.corr()
correlation_matrix
# Out:
#              size_sqft  tiles_count     price
# size_sqft     1.000000     0.988971  0.988971
# tiles_count   0.988971     1.000000  1.000000
# price         0.988971     1.000000  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(correlation_matrix,annot=True,cmap='RdBu_r')
plt.show()

# %%
#remove higjy correlated features (>0.9)
upper=correlation_matrix.where(np.triu(np.ones(correlation_matrix.shape),k=1).astype(bool))
to_drop=[column for column in upper.columns if any(upper[column]>0.9)]
print("Highly correlated features to drop:",to_drop)
# Out:
# Highly correlated features to drop: ['tiles_count', 'price']
